# %% [markdown]
# # Customer Churn Prediction

# %% [markdown]
# ## Importing necessery libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
data = pd.read_excel('customer_churn_large_dataset.xlsx')
data.head()
# Out:
#    CustomerID        Name  Age  Gender     Location  \
# 0           1  Customer_1   63    Male  Los Angeles
# 1           2  Customer_2   62  Female     New York
# 2           3  Customer_3   24  Female  Los Angeles
# 3           4  Customer_4   36  Female        Miami
# 4           5  Customer_5   46  Female        Miami
#
#    Subscription_Length_Months  Monthly_Bill  Total_Usage_GB  Churn
# 0                          17         73.36             236      0
# 1                           1         48.76             172      0
# 2                           5         85.47             460      0
# 3                           3         97.94             297      1
# 4                          19         58.14             266      0

# %%
data.shape
# Out:
# (100000, 9)

# %%
new_data = data.drop(columns=['CustomerID', 'Name'])

print(new_data.shape)
new_data.head(3)
# Out:
# (100000, 7)
#    Age  Gender     Location  Subscription_Length_Months  Monthly_Bill  \
# 0   63    Male  Los Angeles                          17         73.36
# 1   62  Female     New York                           1         48.76
# 2   24  Female  Los Angeles                           5         85.47
#
#    Total_Usage_GB  Churn
# 0             236      0
# 1             172      0
# 2             460      0

# %% [markdown]
# # Perform some EDA to get to know data better
# * Step 1: check for null values and duplicated columns
# * Step 2: Perform Univariate Analysis (Check for distribution of data)
# * Step 3: Perform Bivariate Analysis (Check for correlation b/w colns)

# %%
# check for null values
new_data.isna().sum()
# Out:
# Age                           0
# Gender                        0
# Location                      0
# Subscription_Length_Months    0
# Monthly_Bill                  0
# Total_Usage_GB                0
# Churn                         0
# dtype: int64

# %%
# check for duplicated values
new_data.duplicated().sum()
# Out:
# 0

# %%
# check brief description of data
new_data.describe()
# Out:
#                  Age  Subscription_Length_Months   Monthly_Bill  \
# count  100000.000000               100000.000000  100000.000000
# mean       44.027020                   12.490100      65.053197
# std        15.280283                    6.926461      20.230696
# min        18.000000                    1.000000      30.000000
# 25%        31.000000                    6.000000      47.540000
# 50%        44.000000                   12.000000      65.010000
# 75%        57.000000                   19.000000      82.640000
# max        70.000000                   24.000000     100.000000
#
#        Total_Usage_GB          Churn
# count   100000.000000  100000.000000
# mean       274.393650       0.497790
# std        130.463063       0.499998
# min         50.000000       0.000000
# 25%        161.000000       0.000000
# 50%        274.000000       0.000000
# 75%        387.000000       1.000000
# max        500.000000       1.000000

# %% [markdown]
# # Check for Distribution of Data

# %%
# Loop through each column
for column in new_data.columns:
    # Determine the data type of the column
    dtype = new_data[column].dtype
    
    # If the column is numerical, create a histogram
    if dtype in ['int64', 'float64']:
        plt.figure(figsize=(5, 3))
        sns.histplot(new_data[column], kde=True)
        plt.title(f'Distribution of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.show()
    
    # If the column is categorical, create a count plot
    elif dtype == 'object':
        plt.figure(figsize=(5, 3))
        sns.countplot(data=new_data, x=column)
        plt.title(f'Count of {column}')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.xticks(rotation=45)
        plt.show()

# %% [markdown]
# # Correlation b/w columns

# %%
new_data.sample(1)
# Out:
#        Age Gender Location  Subscription_Length_Months  Monthly_Bill  \
# 56958   40   Male  Chicago                           8         91.32
#
#        Total_Usage_GB  Churn
# 56958             448      1

# %%
# checking for correlation b/w `Age ` and `Subscription_Length_Months` coln
sns.scatterplot(x=new_data['Subscription_Length_Months'], y=new_data['Age'], hue=new_data['Churn'])
# Out:
# <AxesSubplot:xlabel='Subscription_Length_Months', ylabel='Age'>

# %%
# checking for correlation b/w `Age ` and `Monthly_Bill` coln
sns.scatterplot(x=new_data['Monthly_Bill'], y=new_data['Age'], hue=new_data['Churn'])
# Out:
# <AxesSubplot:xlabel='Monthly_Bill', ylabel='Age'>

# %%
# checking for correlation b/w `Age ` and `Total_Usage_GB` coln
sns.scatterplot(x=new_data['Total_Usage_GB'], y=new_data['Age'], hue=new_data['Churn'])
# Out:
# <AxesSubplot:xlabel='Total_Usage_GB', ylabel='Age'>

# %%
# checking for correlation b/w `Subscription_Length_Months` and `Total_Usage_GB` coln
sns.scatterplot(x=new_data['Subscription_Length_Months'], y=new_data['Total_Usage_GB'], hue=new_data['Churn'])
# Out:
# <AxesSubplot:xlabel='Subscription_Length_Months', ylabel='Total_Usage_GB'>

# %% [markdown]
# * By Analyzing this data at this extent, I have got to know this dataset is arranged in the manner as there is no relation b/w any columns and even distributions are very uniformly arranged. It suggests all columns holds equal importance in Model Building.

# %%
new_data.head(1)
# Out:
#    Age Gender     Location  Subscription_Length_Months  Monthly_Bill  \
# 0   63   Male  Los Angeles                          17         73.36
#
#    Total_Usage_GB  Churn
# 0             236      0

# %%
# Divide the data in `features` and `target`
X = new_data.iloc[:, :-1]
y = new_data.iloc[:, -1]

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_validate

# %%
# Divide the data in training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42, shuffle=True)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((90000, 6), (10000, 6), (90000,), (10000,))

# %%
# Differentiate `Categorical` & `Numerical` features
categorical_features = ['Gender', 'Location']
numerical_features = ['Age', 'Subscription_Length_Months', 'Monthly_Bill', 'Total_Usage_GB']

# Create `StandardScalar` and `OneHotEncoder` Object
one_hot_encoder = OneHotEncoder()
standard_scalar = StandardScaler()


# Create ColumnTransformer Object for `Preprocessing Stuff`
preprocesser = ColumnTransformer(transformers=(
    ('encode_gender', one_hot_encoder, categorical_features),
    ('standardization', standard_scalar, numerical_features)
))

# %%
# Create `Model Pipeline` for Logistic Regression
clf = Pipeline(steps=(
    ('preprocessing', preprocesser),
    ('classifier', LogisticRegression())
))

# %%
clf.fit(X_train, y_train)
print("Accuracy score of Logistic Regression is: ", clf.score(X_test, y_test))
# Out:
# Accuracy score of Logistic Regression is:  0.4994

# %%
# Create `Model Pipeline` for `RandomForestClassifier` 
clf2 = Pipeline(steps=[
    ('preprocessing', preprocesser),
    ('classifier', RandomForestClassifier())
])

# %%
clf2.fit(X_train, y_train)
print("The accuracy score of Random Forest Classifier is:", clf2.score(X_test, y_test))
# Out:
# The accuracy score of Random Forest Classifier is: 0.4961

# %% [markdown]
# * General Machine Learning is not showing that good of a result, but actually that's very logical as there was not any relation between features and Machine Learning tries to find the best line matching the relation. So, I hadn't expected anything more.

# %% [markdown]
# # Deep Learning

# %%
import tensorflow as tf
from tensorflow import keras

# %%
# Create `Features` & `Targets`
features = preprocesser.fit_transform(X_train)
targets = y_train

# %%
# Create Model using `Sequential` layer
model = keras.Sequential(layers=[
    keras.layers.Dense(units=64, activation="relu", input_shape=(features.shape[1], )),
    keras.layers.Dropout(rate=0.2),
    keras.layers.Dense(units=128, activation="relu"),
    keras.layers.Dropout(rate=0.2),
    keras.layers.Dense(units=64, activation="relu"),
    keras.layers.Dropout(rate=0.2),
    keras.layers.Dense(units=1, activation="sigmoid")
])

# %%
# Add `Optimizer` and `Loss` function
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
# Check brief summary of model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 17409 (68.00 KB)
# Trainable params: 17409 (68.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Finally time to train the model
model.fit(x=features, y=targets, batch_size=1000, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 72/72 [==============================] - 3s 20ms/step - loss: 0.6948 - accuracy: 0.5001 - val_loss: 0.6941 - val_accuracy: 0.4947
# Epoch 2/50
# 72/72 [==============================] - 1s 18ms/step - loss: 0.6935 - accuracy: 0.5037 - val_loss: 0.6931 - val_accuracy: 0.5073
# Epoch 3/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6934 - accuracy: 0.5029 - val_loss: 0.6932 - val_accuracy: 0.5043
# Epoch 4/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6931 - accuracy: 0.5062 - val_loss: 0.6933 - val_accuracy: 0.4992
# Epoch 5/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6931 - accuracy: 0.5065 - val_loss: 0.6934 - val_accuracy: 0.4969
# Epoch 6/50
# 72/72 [==============================] - 1s 17ms/step - loss: 0.6931 - accuracy: 0.5071 - val_loss: 0.6936 - val_accuracy: 0.4927
# Epoch 7/50
# 72/72 [==============================] - 1s 16ms/step - loss: 0.6931 - accuracy: 0.5054 - val_loss: 0.6933 - val_accuracy: 0.4963
# Epoch 8/50
# 72/72 [==============================] - 1s 17ms/step - loss: 0.6930 - accuracy: 0.5069 - val_loss: 0.6934 - val_accuracy: 0.4957
# Epoch 9/50
# 72/72 [==============================] - 1s 17ms/step - loss: 0.6929 - accuracy: 0.5087 - val_loss: 0.6934 - val_accuracy: 0.4961
# Epoch 10/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6930 - accuracy: 0.5074 - val_loss: 0.6935 - val_accuracy: 0.4957
# Epoch 11/50
# 72/72 [==============================] - 1s 13ms/step - loss: 0.6930 - accuracy: 0.5072 - val_loss: 0.6936 - val_accuracy: 0.4948
# Epoch 12/50
# 72/72 [==============================] - 1s 13ms/step - loss: 0.6928 - accuracy: 0.5116 - val_loss: 0.6936 - val_accuracy: 0.4934
# Epoch 13/50
# 72/72 [==============================] - 1s 13ms/step - loss: 0.6929 - accuracy: 0.5092 - val_loss: 0.6935 - val_accuracy: 0.4962
# Epoch 14/50
# 72/72 [==============================] - 1s 17ms/step - loss: 0.6930 - accuracy: 0.5095 - val_loss: 0.6936 - val_accuracy: 0.4975
# Epoch 15/50
# 72/72 [==============================] - 1s 18ms/step - loss: 0.6928 - accuracy: 0.5105 - val_loss: 0.6935 - val_accuracy: 0.4963
# Epoch 16/50
# 72/72 [==============================] - 1s 18ms/step - loss: 0.6927 - accuracy: 0.5123 - val_loss: 0.6936 - val_accuracy: 0.4974
# Epoch 17/50
# 72/72 [==============================] - 1s 19ms/step - loss: 0.6929 - accuracy: 0.5073 - val_loss: 0.6937 - val_accuracy: 0.4948
# Epoch 18/50
# 72/72 [==============================] - 1s 17ms/step - loss: 0.6928 - accuracy: 0.5108 - val_loss: 0.6935 - val_accuracy: 0.4961
# Epoch 19/50
# 72/72 [==============================] - 1s 17ms/step - loss: 0.6928 - accuracy: 0.5113 - val_loss: 0.6936 - val_accuracy: 0.4990
# Epoch 20/50
# 72/72 [==============================] - 1s 16ms/step - loss: 0.6928 - accuracy: 0.5100 - val_loss: 0.6935 - val_accuracy: 0.5010
# Epoch 21/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6928 - accuracy: 0.5091 - val_loss: 0.6934 - val_accuracy: 0.4966
# Epoch 22/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6926 - accuracy: 0.5110 - val_loss: 0.6936 - val_accuracy: 0.4989
# Epoch 23/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6925 - accuracy: 0.5125 - val_loss: 0.6936 - val_accuracy: 0.4991
# Epoch 24/50
# 72/72 [==============================] - 1s 17ms/step - loss: 0.6928 - accuracy: 0.5107 - val_loss: 0.6934 - val_accuracy: 0.5004
# Epoch 25/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6926 - accuracy: 0.5125 - val_loss: 0.6935 - val_accuracy: 0.4999
# Epoch 26/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6926 - accuracy: 0.5133 - val_loss: 0.6937 - val_accuracy: 0.4969
# Epoch 27/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6925 - accuracy: 0.5127 - val_loss: 0.6936 - val_accuracy: 0.4966
# Epoch 28/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6923 - accuracy: 0.5141 - val_loss: 0.6939 - val_accuracy: 0.5014
# Epoch 29/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6926 - accuracy: 0.5114 - val_loss: 0.6937 - val_accuracy: 0.4989
# Epoch 30/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6925 - accuracy: 0.5142 - val_loss: 0.6938 - val_accuracy: 0.4967
# Epoch 31/50
# 72/72 [==============================] - 1s 18ms/step - loss: 0.6924 - accuracy: 0.5157 - val_loss: 0.6939 - val_accuracy: 0.4982
# Epoch 32/50
# 72/72 [==============================] - 1s 18ms/step - loss: 0.6925 - accuracy: 0.5129 - val_loss: 0.6938 - val_accuracy: 0.4947
# Epoch 33/50
# 72/72 [==============================] - 1s 17ms/step - loss: 0.6925 - accuracy: 0.5155 - val_loss: 0.6937 - val_accuracy: 0.4973
# Epoch 34/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6924 - accuracy: 0.5148 - val_loss: 0.6938 - val_accuracy: 0.4996
# Epoch 35/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6924 - accuracy: 0.5146 - val_loss: 0.6936 - val_accuracy: 0.5009
# Epoch 36/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6924 - accuracy: 0.5148 - val_loss: 0.6937 - val_accuracy: 0.4988
# Epoch 37/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6924 - accuracy: 0.5137 - val_loss: 0.6938 - val_accuracy: 0.4965
# Epoch 38/50
# 72/72 [==============================] - 1s 16ms/step - loss: 0.6922 - accuracy: 0.5151 - val_loss: 0.6937 - val_accuracy: 0.4943
# Epoch 39/50
# 72/72 [==============================] - 1s 18ms/step - loss: 0.6924 - accuracy: 0.5144 - val_loss: 0.6938 - val_accuracy: 0.5009
# Epoch 40/50
# 72/72 [==============================] - 1s 17ms/step - loss: 0.6922 - accuracy: 0.5170 - val_loss: 0.6939 - val_accuracy: 0.4981
# Epoch 41/50
# 72/72 [==============================] - 1s 17ms/step - loss: 0.6923 - accuracy: 0.5160 - val_loss: 0.6939 - val_accuracy: 0.4982
# Epoch 42/50
# 72/72 [==============================] - 1s 17ms/step - loss: 0.6923 - accuracy: 0.5155 - val_loss: 0.6939 - val_accuracy: 0.5031
# Epoch 43/50
# 72/72 [==============================] - 1s 16ms/step - loss: 0.6923 - accuracy: 0.5165 - val_loss: 0.6940 - val_accuracy: 0.4967
# Epoch 44/50
# 72/72 [==============================] - 1s 19ms/step - loss: 0.6922 - accuracy: 0.5167 - val_loss: 0.6940 - val_accuracy: 0.4972
# Epoch 45/50
# 72/72 [==============================] - 1s 17ms/step - loss: 0.6921 - accuracy: 0.5150 - val_loss: 0.6939 - val_accuracy: 0.4956
# Epoch 46/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.6922 - accuracy: 0.5179 - val_loss: 0.6938 - val_accuracy: 0.4945
# Epoch 47/50
# 72/72 [==============================] - 1s 16ms/step - loss: 0.6921 - accuracy: 0.5169 - val_loss: 0.6939 - val_accuracy: 0.4986
# Epoch 48/50
# 72/72 [==============================] - 1s 18ms/step - loss: 0.6920 - accuracy: 0.5178 - val_loss: 0.6941 - val_accuracy: 0.4958
# Epoch 49/50
# 72/72 [==============================] - 1s 16ms/step - loss: 0.6924 - accuracy: 0.5167 - val_loss: 0.6939 - val_accuracy: 0.4976
# Epoch 50/50
# 72/72 [==============================] - 1s 16ms/step - loss: 0.6921 - accuracy: 0.5180 - val_loss: 0.6941 - val_accuracy: 0.4929

# %% [markdown]
# * Even a well curated Deep Learning model was not able to get accuracy over 51% on validation set. At the very least this was expected with the dataset it was training on.

# %%
# Test the model
test_features = preprocesser.transform(X_test)
test_targets = y_test

model.evaluate(test_features, test_targets)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6946 - accuracy: 0.4963
# [0.6945743560791016, 0.49630001187324524]

# %% [markdown]
# * Though I was not able to get better accuracy on this dataset, and I think dataset is also on partially fault there. But now let's move forward to next step and that is deploy this model on Streamlit Website.

# %%
# Deploy the model using `pickle` module
import pickle

pickle.dump(clf, open("model.pkl", 'wb'))

# %%
# Loading the saved model
loaded_model = pickle.load(open('model.pkl', 'rb'))
